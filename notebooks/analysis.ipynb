# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import wandb

# %%
# api = wandb.Api(api_key="<API_KEY>",timeout=50)
api = wandb.Api()

# %%
def extract_runs(api: wandb.Api, workspace: str = "ludekcizinsky/seizure-prediction"):
    runs = api.runs("ludekcizinsky/seizure-prediction")
    runs_list = []
    for run in runs:
        tags = list(run.tags)
        has_cross_val = "fold_0" in tags or "fold_1" in tags or "fold_2" in tags
        if not has_cross_val:
            continue

        filtered_tags = [tag for tag in tags if not tag.startswith("fold_") and not tag.startswith("part")]
        key = "_".join(sorted(filtered_tags))
        fold_id = run.config["fold_id"]
        

        for step in run.scan_history():
            if "val/f1_macro" not in step or not step["val/f1_macro"]:
                continue
            run_dict = {
                "key": key,
                "name": run.name,
                "fold_id": fold_id,
                "epoch": step.get("epoch", None),
                "val_accuracy": step.get("val/acc", None),
                "val_f1": step.get("val/f1_macro", None),
                "val_f1_plus": step.get("val/f1_class_1",None),
                "val_f1_neg": step.get("val/f1_class_0",None),
                "val_loss": step.get("val/loss", None)
            }
            runs_list.append(run_dict)
    runs_df = pd.DataFrame(runs_list).sort_values(by=["key", "fold_id"])
    runs_df = runs_df.groupby(["key", "epoch"]).agg({
        "val_f1": "mean",
        "val_f1_plus": "mean",
        "val_f1_neg": "mean",
        "val_accuracy": "mean",
        "val_loss": "mean",
        "name": "first"
    }).reset_index()
    return runs_df

# %%
runs_df = extract_runs(api)

# %%
runs_df.iloc[runs_df.groupby("key").idxmax()["val_f1"].reset_index()["val_f1"].to_list()].sort_values(by="val_f1",ascending=False)
# Out:
#                                                   key  epoch    val_f1  \
# 98                                baseline_conv1d_fft    474  0.840546
# 272                             baseline_fft_tencoder    824  0.835179
# 230                                 baseline_fft_lstm    774  0.835041
# 523             dist_1_5_lstm learned_pool_window_gcn     47  0.795578
# 547         dist_1_5_lstm_att learned_pool_window_gcn     45  0.790375
# 474      dist_1_5_kaggle_lstm learned_pool_window_gcn     49  0.786747
# 498  dist_1_5_kaggle_lstm_att learned_pool_window_gcn     47  0.784797
# 431                     dist_1_5_fft_gcn_learned_pool    549  0.782500
# 730                              fft_gcn_learned_pool    899  0.781911
# 359                         corr_fft_gcn_learned_pool    749  0.776973
# 294   conv1dn learned_pool_dist_1_5_kaggle_window_gcn     29  0.771717
# 681                fft_gcn_learnable_adj_learned_pool    674  0.764868
# 319          conv1dn learned_pool_dist_1_5_window_gcn     29  0.762535
# 408                     dist_0_5_fft_gcn_learned_pool    974  0.760584
# 569         dist_1_5_tencoder learned_pool_window_gcn     39  0.756233
# 199                                  baseline_fft_gcn    999  0.747746
# 767                                  fft_gcn_max_pool    824  0.744516
# 78                                   add_pool_fft_gcn    974  0.739306
# 600                              fft_gat_learned_pool    649  0.717542
# 158                                  baseline_fft_gat    974  0.708366
# 654                                  fft_gat_max_pool    999  0.669206
# 22                                   add_pool_fft_gat    574  0.649428
#
#      val_f1_plus  val_f1_neg  val_accuracy  val_loss                   name
# 98      0.738908    0.942185      0.905334  0.711557       tough-cherry-335
# 272     0.727594    0.942764      0.905411  1.091691          denim-sun-329
# 230     0.733113    0.936968      0.898022  0.379498           dark-dew-328
# 523     0.659600    0.931555      0.886054  0.330168        apricot-fog-389
# 547     0.652393    0.928356      0.881205  0.320345        fresh-blaze-396
# 474     0.645777    0.927718      0.879935  0.341065     gentle-firefly-387
# 498     0.648649    0.920945      0.870930  0.323083   generous-terrain-394
# 431     0.641074    0.923926      0.874471  0.403612         clean-haze-367
# 730     0.641377    0.922445      0.872470  1.078126       desert-shape-343
# 359     0.633556    0.920390      0.869237  0.744131         lucky-hill-362
# 294     0.632882    0.910553      0.856153  0.385809         young-lake-388
# 681     0.612365    0.917371      0.863850  0.471079     fearless-plant-371
# 319     0.625210    0.899859      0.841953  0.389234        zany-breeze-390
# 408     0.608059    0.913110      0.857770  1.834111     colorful-voice-363
# 569     0.602546    0.909920      0.853229  0.633160       eternal-moon-393
# 199     0.577707    0.917785      0.862464  0.379735  misunderstood-sky-327
# 767     0.573274    0.915758      0.859309  0.378518      winter-flower-342
# 78      0.563723    0.914889      0.857616  0.373523        pious-salad-351
# 600     0.518891    0.916193      0.857385  0.611904   devoted-capybara-357
# 158     0.517130    0.899603      0.833834  0.437981    classic-silence-336
# 654     0.426582    0.911830      0.847379  0.395612         swept-leaf-343
# 22      0.391460    0.907396      0.839991  0.818262        smart-music-353

# %%
runs_df[runs_df["key"] == "dist_0_5_fft_gcn_learned_pool"]["val_f1"].max()
# Out:
# np.float64(0.7605843941370646)

# %%
runs_df[runs_df["key"] == "dist_1_5_fft_gcn_learned_pool"]["val_f1"].max()
# Out:
# np.float64(0.7825000087420145)

# %%
runs_df[runs_df["key"] == "fft_gcn_learnable_adj_learned_pool"]["val_f1"].max()
# Out:
# np.float64(0.7648681402206421)

# %%
runs_df[runs_df["key"] == "corr_fft_gcn_learned_pool"]["val_f1"].max()
# Out:
# np.float64(0.7769731879234314)

# %%
runs_df[runs_df["key"] == "fft_gcn_learned_pool"]["val_f1"].max()
# Out:
# np.float64(0.7819106976191202)
